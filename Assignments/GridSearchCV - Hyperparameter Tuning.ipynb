# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("concrete_data.csv")
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
X = data.iloc[:, :8].values
Y = data.iloc[:, 8].values.reshape(-1, 1)

# %%
print(np.shape(X))
print(np.shape(Y))
# Out:
# (1030, 8)
# (1030, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2021)

# %%
from xgboost import XGBRegressor
xgb_model = XGBRegressor(random_state = 2021)

# %%
# make a dictionary of hyperparameter values to search
search_space = {
    "n_estimators" : [100, 200, 500],
    "max_depth" : [3, 6, 9],
    "gamma" : [0.01, 0.1],
    "learning_rate" : [0.001, 0.01, 0.1, 1]
}

# %%
from sklearn.model_selection import GridSearchCV
# make a GridSearchCV object
GS = GridSearchCV(estimator = xgb_model,
                  param_grid = search_space,
                  scoring = ["r2", "neg_root_mean_squared_error"], #sklearn.metrics.SCORERS.keys()
                  refit = "r2",
                  cv = 5,
                  verbose = 4)

# %%
GS.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-35.192, r2=-3.685, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100 ..
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-36.463, r2=-4.022, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-35.801, r2=-3.374, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100 ..
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-35.460, r2=-3.748, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-37.090, r2=-3.535, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-32.121, r2=-2.903, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-33.338, r2=-3.198, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-32.709, r2=-2.652, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-32.387, r2=-2.961, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-33.937, r2=-2.796, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-24.537, r2=-1.278, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-25.718, r2=-1.498, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-25.107, r2=-1.151, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-24.870, r2=-1.336, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-26.223, r2=-1.267, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-35.102, r2=-3.661, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-36.470, r2=-4.024, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-35.790, r2=-3.372, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-35.434, r2=-3.741, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-37.040, r2=-3.522, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-31.984, r2=-2.870, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-33.305, r2=-3.189, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-32.661, r2=-2.641, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-32.297, r2=-2.939, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-33.818, r2=-2.770, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-24.302, r2=-1.234, total=   0.7s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-25.530, r2=-1.462, total=   0.7s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-24.919, r2=-1.119, total=   0.7s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-24.662, r2=-1.297, total=   0.7s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-25.872, r2=-1.206, total=   0.7s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-35.095, r2=-3.659, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-36.465, r2=-4.022, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-35.788, r2=-3.371, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-35.434, r2=-3.741, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-37.039, r2=-3.522, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-31.977, r2=-2.868, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-33.296, r2=-3.187, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-32.656, r2=-2.640, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-32.297, r2=-2.939, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-33.825, r2=-2.771, total=   0.6s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-24.297, r2=-1.233, total=   1.1s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-25.515, r2=-1.459, total=   0.9s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-24.920, r2=-1.119, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-24.677, r2=-1.300, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500 ..
# [CV]  gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-25.887, r2=-1.209, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-16.098, r2=0.020, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-17.399, r2=-0.143, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-16.667, r2=0.052, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-16.650, r2=-0.047, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-17.677, r2=-0.030, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-8.566, r2=0.722, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-9.848, r2=0.634, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-9.152, r2=0.714, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-9.269, r2=0.676, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-10.315, r2=0.649, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-5.062, r2=0.903, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-6.040, r2=0.862, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-5.558, r2=0.895, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-5.982, r2=0.865, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-7.111, r2=0.833, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-15.530, r2=0.088, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-16.800, r2=-0.066, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-16.094, r2=0.116, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-16.096, r2=0.022, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-16.987, r2=0.049, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-7.548, r2=0.784, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-8.661, r2=0.717, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-8.127, r2=0.775, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-8.211, r2=0.745, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-8.948, r2=0.736, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.362, r2=0.928, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-5.085, r2=0.902, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.755, r2=0.923, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.930, r2=0.908, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-5.927, r2=0.884, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-15.512, r2=0.090, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-16.758, r2=-0.061, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-16.097, r2=0.116, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-16.090, r2=0.022, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-17.016, r2=0.046, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-7.535, r2=0.785, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-8.648, r2=0.718, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-8.129, r2=0.774, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-8.099, r2=0.752, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-8.819, r2=0.744, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.362, r2=0.928, total=   1.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.791, r2=0.913, total=   1.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.751, r2=0.923, total=   1.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.731, r2=0.915, total=   1.2s
# [CV] gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-5.733, r2=0.892, total=   1.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-4.425, r2=0.926, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-5.440, r2=0.888, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-4.848, r2=0.920, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-5.324, r2=0.893, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-6.584, r2=0.857, total=   0.1s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-4.039, r2=0.938, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-5.114, r2=0.901, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-4.539, r2=0.930, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-4.890, r2=0.910, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-6.211, r2=0.873, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-3.750, r2=0.947, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-4.785, r2=0.914, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-4.276, r2=0.938, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-4.621, r2=0.919, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-5.920, r2=0.884, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-4.065, r2=0.937, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-4.990, r2=0.906, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-4.327, r2=0.936, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-4.622, r2=0.919, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-5.790, r2=0.890, total=   0.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-4.058, r2=0.938, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-4.865, r2=0.911, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-4.286, r2=0.937, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-4.386, r2=0.927, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-5.684, r2=0.894, total=   0.4s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.069, r2=0.937, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.778, r2=0.914, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.285, r2=0.937, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.373, r2=0.928, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-5.673, r2=0.894, total=   0.8s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-4.163, r2=0.934, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-4.481, r2=0.924, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-4.603, r2=0.928, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-4.682, r2=0.917, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-5.628, r2=0.896, total=   0.3s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-4.144, r2=0.935, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-4.427, r2=0.926, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-4.613, r2=0.927, total=   1.0s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-4.685, r2=0.917, total=   0.6s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-5.613, r2=0.896, total=   0.5s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.145, r2=0.935, total=   1.0s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.425, r2=0.926, total=   1.2s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.613, r2=0.927, total=   1.0s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.686, r2=0.917, total=   1.1s
# [CV] gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500 ....
# [CV]  gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-5.612, r2=0.896, total=   1.0s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-4.760, r2=0.914, total=   0.1s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-5.582, r2=0.882, total=   0.1s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-5.078, r2=0.912, total=   0.1s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-4.768, r2=0.914, total=   0.1s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-6.210, r2=0.873, total=   0.1s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-4.667, r2=0.918, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-5.479, r2=0.887, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-5.284, r2=0.905, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-4.765, r2=0.914, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-6.150, r2=0.875, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-4.722, r2=0.916, total=   0.5s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-5.529, r2=0.885, total=   0.5s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-5.322, r2=0.903, total=   0.5s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-4.762, r2=0.914, total=   0.5s
# [CV] gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-6.220, r2=0.872, total=   0.5s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-6.749, r2=0.828, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-6.195, r2=0.855, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-6.953, r2=0.835, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-5.799, r2=0.873, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-6.935, r2=0.841, total=   0.2s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-6.749, r2=0.828, total=   0.3s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-6.195, r2=0.855, total=   0.3s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-6.953, r2=0.835, total=   0.3s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-5.799, r2=0.873, total=   0.3s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-6.935, r2=0.841, total=   0.3s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-6.749, r2=0.828, total=   0.7s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-6.195, r2=0.855, total=   0.8s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-6.953, r2=0.835, total=   0.6s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-5.799, r2=0.873, total=   0.8s
# [CV] gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-6.935, r2=0.841, total=   1.1s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-7.556, r2=0.784, total=   0.4s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-6.750, r2=0.828, total=   0.3s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-6.873, r2=0.839, total=   0.3s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-6.153, r2=0.857, total=   0.3s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-6.977, r2=0.840, total=   0.3s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-7.556, r2=0.784, total=   0.6s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-6.750, r2=0.828, total=   0.4s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-6.873, r2=0.839, total=   0.4s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-6.153, r2=0.857, total=   0.5s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-6.977, r2=0.840, total=   0.6s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-7.556, r2=0.784, total=   1.4s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-6.750, r2=0.828, total=   1.0s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-6.873, r2=0.839, total=   1.5s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-6.153, r2=0.857, total=   1.4s
# [CV] gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500 ......
# [CV]  gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-6.977, r2=0.840, total=   1.7s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-35.192, r2=-3.685, total=   0.1s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-36.463, r2=-4.022, total=   0.1s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-35.801, r2=-3.374, total=   0.1s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-35.460, r2=-3.748, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-37.090, r2=-3.535, total=   0.1s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-32.121, r2=-2.903, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-33.338, r2=-3.198, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-32.709, r2=-2.652, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-32.387, r2=-2.961, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-33.937, r2=-2.796, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-24.537, r2=-1.278, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-25.718, r2=-1.498, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-25.107, r2=-1.151, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-24.870, r2=-1.336, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-26.223, r2=-1.267, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-35.102, r2=-3.661, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-36.470, r2=-4.024, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-35.790, r2=-3.372, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-35.434, r2=-3.741, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-37.040, r2=-3.522, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-31.984, r2=-2.870, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-33.305, r2=-3.189, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-32.661, r2=-2.641, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-32.297, r2=-2.939, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-33.818, r2=-2.770, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-24.302, r2=-1.234, total=   0.8s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-25.530, r2=-1.462, total=   0.7s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-24.919, r2=-1.119, total=   0.7s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-24.663, r2=-1.297, total=   0.7s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-25.872, r2=-1.206, total=   0.7s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-35.095, r2=-3.659, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-36.465, r2=-4.022, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-35.788, r2=-3.371, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-35.434, r2=-3.741, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-37.039, r2=-3.522, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-31.977, r2=-2.868, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-33.296, r2=-3.187, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-32.656, r2=-2.640, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-32.297, r2=-2.939, total=   0.4s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-33.825, r2=-2.771, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-24.297, r2=-1.233, total=   0.8s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-25.515, r2=-1.459, total=   0.8s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-24.919, r2=-1.119, total=   0.8s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-24.677, r2=-1.299, total=   0.8s
# [CV] gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500 ...
# [CV]  gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-25.886, r2=-1.209, total=   0.8s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-16.098, r2=0.020, total=   0.1s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-17.399, r2=-0.143, total=   0.1s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-16.667, r2=0.052, total=   0.1s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-16.650, r2=-0.047, total=   0.1s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-17.677, r2=-0.030, total=   0.1s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-8.566, r2=0.722, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-9.848, r2=0.634, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-9.152, r2=0.714, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-9.269, r2=0.676, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-10.315, r2=0.649, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-5.062, r2=0.903, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500 ....
# [CV]  gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-6.040, r2=0.862, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500 ....
# ...
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-4.979, r2=0.906, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-4.349, r2=0.935, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-4.566, r2=0.921, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-5.835, r2=0.888, total=   0.2s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-4.009, r2=0.939, total=   0.4s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-4.840, r2=0.912, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-4.260, r2=0.938, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-4.350, r2=0.929, total=   0.4s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-5.683, r2=0.894, total=   0.4s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.022, r2=0.939, total=   0.7s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.773, r2=0.914, total=   0.8s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.262, r2=0.938, total=   0.8s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-4.342, r2=0.929, total=   0.7s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-5.658, r2=0.894, total=   0.8s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-4.178, r2=0.934, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-4.434, r2=0.926, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-4.606, r2=0.928, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-4.709, r2=0.916, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-5.664, r2=0.894, total=   0.3s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-4.186, r2=0.934, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-4.414, r2=0.926, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-4.613, r2=0.927, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-4.700, r2=0.917, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-5.659, r2=0.894, total=   0.5s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.186, r2=0.934, total=   0.9s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.414, r2=0.926, total=   1.0s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.613, r2=0.927, total=   1.1s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-4.700, r2=0.917, total=   1.0s
# [CV] gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500 .....
# [CV]  gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-5.659, r2=0.894, total=   0.9s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-4.640, r2=0.919, total=   0.1s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-5.466, r2=0.887, total=   0.1s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-5.046, r2=0.913, total=   0.1s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-4.768, r2=0.914, total=   0.1s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100, neg_root_mean_squared_error=-6.210, r2=0.873, total=   0.1s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-4.711, r2=0.916, total=   0.2s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-5.292, r2=0.894, total=   0.2s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-5.164, r2=0.909, total=   0.2s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-4.721, r2=0.916, total=   0.2s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200, neg_root_mean_squared_error=-6.131, r2=0.876, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-4.707, r2=0.916, total=   0.5s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-5.239, r2=0.896, total=   0.6s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-5.163, r2=0.909, total=   0.9s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-4.740, r2=0.915, total=   0.7s
# [CV] gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500, neg_root_mean_squared_error=-6.184, r2=0.874, total=   0.6s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-6.766, r2=0.827, total=   0.2s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-6.324, r2=0.849, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-7.095, r2=0.828, total=   0.4s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-5.581, r2=0.882, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100, neg_root_mean_squared_error=-6.833, r2=0.846, total=   0.5s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-6.766, r2=0.827, total=   0.7s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-6.324, r2=0.849, total=   0.7s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-7.095, r2=0.828, total=   0.4s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-5.581, r2=0.882, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200, neg_root_mean_squared_error=-6.833, r2=0.846, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-6.766, r2=0.827, total=   0.7s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-6.324, r2=0.849, total=   0.7s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-7.095, r2=0.828, total=   0.7s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-5.581, r2=0.882, total=   0.8s
# [CV] gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500, neg_root_mean_squared_error=-6.833, r2=0.846, total=   0.8s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-7.583, r2=0.782, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-6.699, r2=0.830, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-6.841, r2=0.840, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-6.126, r2=0.858, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100, neg_root_mean_squared_error=-6.854, r2=0.845, total=   0.3s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-7.583, r2=0.782, total=   0.5s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-6.699, r2=0.830, total=   0.5s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-6.841, r2=0.840, total=   0.6s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-6.126, r2=0.858, total=   0.5s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200, neg_root_mean_squared_error=-6.854, r2=0.845, total=   0.5s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-7.583, r2=0.782, total=   1.2s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-6.699, r2=0.830, total=   1.2s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-6.841, r2=0.840, total=   1.4s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-6.126, r2=0.858, total=   1.1s
# [CV] gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500 .......
# [CV]  gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500, neg_root_mean_squared_error=-6.854, r2=0.845, total=   1.3s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed:  2.7min finished
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     enable_categorical=False, gamma=None,
#                                     gpu_id=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n...
#                                     num_parallel_tree=None, predictor=None,
#                                     random_state=2021, reg_alpha=None,
#                                     reg_lambda=None, scale_pos_weight=None,
#                                     subsample=None, tree_method=None,
#                                     validate_parameters=None, verbosity=None),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [100, 200, 500]},
#              refit='r2', scoring=['r2', 'neg_root_mean_squared_error'],
#              verbose=4)

# %%
print(GS.best_estimator_) # to get the complete detail of the best model
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0.1, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=500, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=2021,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
print(GS.best_params_) # to get only the best hyperparameter values that we searched for
# Out:
# {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}

# %%
print(GS.best_score_) # score according to the metric we passed in refit
# Out:
# 0.9228097089517535

# %%
df = pd.DataFrame(GS.cv_results_)
df = df.sort_values("rank_test_r2")
df.to_csv("cv_result.csv")
