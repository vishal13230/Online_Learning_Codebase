# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")
import seaborn as sns

# %%
df = pd.read_csv("titanic_train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x = "Survived", data = df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = "Survived", hue = "Sex", data = df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = "Survived", hue = "Pclass", data = df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.displot(df["Age"].dropna(), bins = 40, kde = True)

# %%
df["Age"].hist(bins = 30, alpha = 0.4)
# Out:
# <AxesSubplot:>

# %%
def func(*args):
    # args will be a tuple containing all values that are passed in
    for i in args:
        print(i)
    
func("a",2,45,67,"gb")
# Out:
# a
# 2
# 45
# 67
# gb

# %%
people = {
    "first": ["Nivesh", "Vishal", "Prabhat"],
    "last": ["rastogi", "raj", "kumar"],
    "salary": [20000, 30000, 40000]
}

# %%
people
# Out:
# {'first': ['Nivesh', 'Vishal', 'Prabhat'],
#  'last': ['rastogi', 'raj', 'kumar'],
#  'salary': [20000, 30000, 40000]}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df.set_index("salary", inplace=True)

# %%
df
# Out:
#           first     last
# salary
# 20000    Nivesh  rastogi
# 30000    Vishal      raj
# 40000   Prabhat    kumar

# %%
df.index
# Out:
# Int64Index([20000, 30000, 40000], dtype='int64', name='salary')

# %%
df.loc[20000]
# Out:
# first     Nivesh
# last     rastogi
# Name: 20000, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    salary    first     last
# 0   20000   Nivesh  rastogi
# 1   30000   Vishal      raj
# 2   40000  Prabhat    kumar
