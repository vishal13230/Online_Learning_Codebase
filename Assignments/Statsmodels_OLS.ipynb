# %%
# Import the libraries
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# Load the data
data = sm.datasets.get_rdataset("Guerry", "HistData").data
data.head()
# Out:
#    dept Region    Department  Crime_pers  Crime_prop  ...  Instruction  Prostitutes  Distance  Area Pop1831
# 0     1      E           Ain       28870       15890  ...           46           13   218.372  5762  346.03
# 1     2      N         Aisne       26226        5521  ...           24          327    65.945  7369  513.00
# 2     3      C        Allier       26747        7925  ...           85           34   161.927  7340  298.26
# 3     4      E  Basses-Alpes       12935        7289  ...           29            2   351.399  6925  155.90
# 4     5      E  Hautes-Alpes       17488        8174  ...            7            1   320.280  5549  129.10
#
# [5 rows x 23 columns]

# %%
# Fit regression model (using the natural log of one of the regressors)
results = smf.ols("Lottery ~ Literacy + np.log(Pop1831)", data = data).fit()

# %%
# Print the result
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     22.20
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):           1.90e-08
# Time:                        23:07:12   Log-Likelihood:                -379.82
# No. Observations:                  86   AIC:                             765.6
# Df Residuals:                      83   BIC:                             773.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         246.4341     35.233      6.995      0.000     176.358     316.510
# Literacy           -0.4889      0.128     -3.832      0.000      -0.743      -0.235
# np.log(Pop1831)   -31.3114      5.977     -5.239      0.000     -43.199     -19.424
# ==============================================================================
# Omnibus:                        3.713   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.156   Jarque-Bera (JB):                3.394
# Skew:                          -0.487   Prob(JB):                        0.183
# Kurtosis:                       3.003   Cond. No.                         702.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
